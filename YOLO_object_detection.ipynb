# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirAzz/Test/blob/main/YOLO_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Active GPU** :First of all , Go to Runtime and select change Runtimetype and from hardware accelarator select :GPU
# then write the following code for check is GPU active or no ?

# %%
# !nvidia-smi
# Out:
# Tue Jul 18 10:30:20 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   62C    P8    11W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %% [markdown]
# **Next ,Install ultralytics .this is the main library of YOLO**

# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 605.4/605.4 kB 10.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **then import YOLO to your notebook**

# %%
from ultralytics import YOLO

# %%
from IPython.display import display, Image

# %% [markdown]
# **Inference with Pre-trained COCO Model**(Try with other model :just change model=yolo8n.pt to: yolo8s.pt /yolo8m.pt/yolo8l.pt and yolo8x.pt and compare the results

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/Asociatyvi-nuotrauka-1-scaled.jpg' save=True
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/Asociatyvi-nuotrauka-1-scaled.jpg: 448x640 8 persons, 1 bench, 63.8ms
# Speed: 3.7ms preprocess, 63.8ms inference, 90.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
Image(filename='/content/runs/detect/predict/Asociatyvi-nuotrauka-1-scaled.jpg', height=600)

# %% [markdown]
# **do the same steps for video **

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source='/content/production_id_3740032 (2160p).mp4' save=True
# Out:
# Ultralytics YOLOv8.0.136 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# video 1/1 (1/539) /content/production_id_3740032 (2160p).mp4: 384x640 12 persons, 1 train, 3 suitcases, 2 skateboards, 63.1ms
# video 1/1 (2/539) /content/production_id_3740032 (2160p).mp4: 384x640 12 persons, 1 car, 1 train, 3 suitcases, 9.2ms
# video 1/1 (3/539) /content/production_id_3740032 (2160p).mp4: 384x640 11 persons, 1 train, 1 backpack, 3 suitcases, 10.1ms
# video 1/1 (4/539) /content/production_id_3740032 (2160p).mp4: 384x640 12 persons, 1 train, 3 suitcases, 9.1ms
# video 1/1 (5/539) /content/production_id_3740032 (2160p).mp4: 384x640 11 persons, 3 suitcases, 8.6ms
# video 1/1 (6/539) /content/production_id_3740032 (2160p).mp4: 384x640 13 persons, 1 train, 1 backpack, 3 suitcases, 8.3ms
# video 1/1 (7/539) /content/production_id_3740032 (2160p).mp4: 384x640 12 persons, 1 train, 1 backpack, 3 suitcases, 8.3ms
# ...

# %% [markdown]
# please check this link for more documents :https://docs.ultralytics.com/
